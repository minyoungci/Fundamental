# %%
import numpy as np
import matplotlib.pyplot as plt

# 두 벡터 정의
v1 = np.array([1, 2])
v2 = np.array([2, 1])

# Span을 시각화하기 위해 다양한 선형 결합을 생성
a_vals = np.linspace(-2, 2, 10)
b_vals = np.linspace(-2, 2, 10)

# 격자 생성
A, B = np.meshgrid(a_vals, b_vals)
span_points = np.array([a * v1 + b * v2 for a, b in zip(A.flatten(), B.flatten())])

# 시각화
plt.figure(figsize=(8, 8))
plt.quiver(0, 0, v1[0], v1[1], angles='xy', scale_units='xy', scale=1, color='r', label='v1')
plt.quiver(0, 0, v2[0], v2[1], angles='xy', scale_units='xy', scale=1, color='b', label='v2')
plt.scatter(span_points[:, 0], span_points[:, 1], color='g', s=5, label='span points')

plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()
plt.title('Span of Vectors v1 and v2')
plt.show()
# Out:
# /home/minyoungxi/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) NanumGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install manim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting manim
#   Downloading manim-0.18.1-py3-none-any.whl (585 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.2/585.2 KB 19.4 MB/s eta 0:00:00
# Collecting pydub>=0.20.0
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: scipy>=1.6.0 in /home/minyoungxi/.local/lib/python3.10/site-packages (from manim) (1.11.4)
# Collecting mapbox-earcut>=1.0.0
#   Downloading mapbox_earcut-1.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 KB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.0.0 in /home/minyoungxi/.local/lib/python3.10/site-packages (from manim) (4.65.0)
# Collecting cloup>=2.0.0
#   Downloading cloup-3.0.5-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 KB 21.0 MB/s eta 0:00:00
# Collecting manimpango<1.0.0,>=0.5.0
#   Using cached ManimPango-0.5.0-cp310-cp310-linux_x86_64.whl
# Collecting moderngl-window>=2.0.0
#   Downloading moderngl_window-2.4.6-py3-none-any.whl (370 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.6/370.6 KB 30.8 MB/s eta 0:00:00
# Collecting srt>=3.0.0
#   Using cached srt-3.5.3-py3-none-any.whl
# Collecting screeninfo>=0.7
#   Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Collecting rich>=12.0.0
#   Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Collecting typing-extensions>=4.0.0
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: Pillow>=9.1 in /home/minyoungxi/.local/lib/python3.10/site-packages (from manim) (10.3.0)
# Collecting svgelements>=1.8.0
#   Downloading svgelements-1.9.6-py2.py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 KB 28.5 MB/s eta 0:00:00
# Collecting skia-pathops>=0.7.0
#   Downloading skia_pathops-0.8.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 42.6 MB/s eta 0:00:00m eta 0:00:010:01
# Requirement already satisfied: pycairo<2.0.0,>=1.13 in /usr/lib/python3/dist-packages (from manim) (1.20.1)
# Requirement already satisfied: numpy>=1.26 in /home/minyoungxi/.local/lib/python3.10/site-packages (from manim) (1.26.4)
# Collecting isosurfaces>=0.1.0
#   Downloading isosurfaces-0.1.2-py3-none-any.whl (11 kB)
# Collecting watchdog>=2.0.0
#   Downloading watchdog-4.0.1-py3-none-manylinux2014_x86_64.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 KB 50.0 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=4.3.2 in /home/minyoungxi/.local/lib/python3.10/site-packages (from manim) (5.1.1)
# Collecting moderngl<6.0.0,>=5.0.0
#   Downloading moderngl-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.7/267.7 KB 50.7 MB/s eta 0:00:00
# Requirement already satisfied: Pygments>=2.0.0 in /usr/lib/python3/dist-packages (from manim) (2.11.2)
# Collecting networkx>=2.6
#   Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: click>=8.0 in /usr/lib/python3/dist-packages (from manim) (8.0.3)
# Collecting glcontext<3,>=2.5.0
#   Downloading glcontext-2.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 KB 33.1 MB/s eta 0:00:00
# Collecting pyglet>=2.0.0
#   Downloading pyglet-2.0.16-py3-none-any.whl (929 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 929.1/929.1 KB 50.7 MB/s eta 0:00:00
# Collecting pyrr<1,>=0.10.3
#   Downloading pyrr-0.10.3-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 KB 24.3 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting Pygments>=2.0.0
#   Using cached pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting multipledispatch
#   Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Installing collected packages: svgelements, pydub, multipledispatch, glcontext, watchdog, typing-extensions, srt, skia-pathops, screeninfo, pyrr, Pygments, pyglet, networkx, moderngl, mdurl, mapbox-earcut, manimpango, isosurfaces, cloup, moderngl-window, markdown-it-py, rich, manim
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.13.0 requires wrapt>=1.11.0, which is not installed.
# tensorflow 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.26.4 which is incompatible.
# tensorflow 2.13.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.12.4 which is incompatible.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# Successfully installed Pygments-2.18.0 cloup-3.0.5 glcontext-2.5.0 isosurfaces-0.1.2 manim-0.18.1 manimpango-0.5.0 mapbox-earcut-1.0.1 markdown-it-py-3.0.0 mdurl-0.1.2 moderngl-5.10.0 moderngl-window-2.4.6 multipledispatch-1.0.0 networkx-3.3 pydub-0.25.1 pyglet-2.0.16 pyrr-0.10.3 rich-13.7.1 screeninfo-0.8.1 skia-pathops-0.8.0.post1 srt-3.5.3 svgelements-1.9.6 typing-extensions-4.12.2 watchdog-4.0.1

# %%
from manim import *

class VectorSpan(Scene):
    def construct(self):
        # 두 벡터 정의
        v1 = np.array([2, 1, 0])
        v2 = np.array([1, 2, 0])
        
        # 배경 그리드 추가
        grid = NumberPlane()
        self.add(grid)
        
        # 벡터 추가
        vec1 = Arrow(ORIGIN, v1, buff=0, color=RED)
        vec2 = Arrow(ORIGIN, v2, buff=0, color=BLUE)
        
        self.play(Create(vec1), Create(vec2))
        
        # 벡터에 레이블 추가
        label1 = MathTex(r"\vec{v}_1").next_to(vec1.get_end(), RIGHT)
        label2 = MathTex(r"\vec{v}_2").next_to(vec2.get_end(), UP)
        
        self.play(Write(label1), Write(label2))
        
        # Span 시각화
        span_area = Polygon(ORIGIN, v1, v1+v2, v2, color=GREEN, fill_opacity=0.5)
        self.play(Create(span_area))
        
        # 설명 텍스트 추가
        span_text = Text("Span of $\\vec{v}_1$ and $\\vec{v}_2$", font_size=24).to_edge(UP)
        self.play(Write(span_text))
        
        self.wait(2)

# Manim 명령어
# manim -pql script_name.py VectorSpan
# Out:
# Manim Community v0.18.1
#
# Traceback (most recent call last):
#   File "/home/minyoungxi/.local/bin/manim", line 8, in <module>
#     sys.exit(main())
#   File "/usr/lib/python3/dist-packages/click/core.py", line 1128, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/lib/python3/dist-packages/click/core.py", line 1053, in main
#     rv = self.invoke(ctx)
#   File "/usr/lib/python3/dist-packages/click/core.py", line 1659, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/usr/lib/python3/dist-packages/click/core.py", line 1395, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/lib/python3/dist-packages/click/core.py", line 754, in invoke
#     return __callback(*args, **kwargs)
#   File "/home/minyoungxi/.local/lib/python3.10/site-packages/manim/cli/render/commands.py", line 116, in render
#     for SceneClass in scene_classes_from_file(file):
#   File "/home/minyoungxi/.local/lib/python3.10/site-packages/manim/utils/module_ops.py", line 131, in scene_classes_from_file
#     module = get_module(file_path)
#   File "/home/minyoungxi/.local/lib/python3.10/site-packages/manim/utils/module_ops.py", line 57, in get_module
#     raise FileNotFoundError(f"{file_name} not found")
# FileNotFoundError: /home/minyoungxi/MINYOUNGXI/Fundamental/Linear Algebra/script_name.py not found
